# %%
import pandas as pd

# %%
df = pd.read_csv("insurance_fraud_data.csv")

# %%
df
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 1            269568             33      M              1             72
# 2            974592             31      M              1             76
# 3            995328             53      F              1             93
# 4           1140480             41      M              1             87
# ...             ...            ...    ...            ...            ...
# 11997     621727488             34      M              1             88
# 11998     621810432             65      F              1             97
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...

# %%
#1
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12002 entries, 0 to 12001
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   claim_number        12002 non-null  int64
#  1   age_of_driver       12002 non-null  int64
#  2   gender              12002 non-null  object
#  3   marital_status      12002 non-null  object
#  4   safety_rating       12002 non-null  int64
#  5   annual_income       12002 non-null  float64
#  6   high_education      12002 non-null  int64
#  7   address_change      12002 non-null  int64
#  8   property_status     12002 non-null  object
#  9   zip_code            12002 non-null  int64
#  10  claim_date          12002 non-null  object
#  11  claim_day_of_week   12002 non-null  object
#  12  accident_site       12002 non-null  object
#  13  past_num_of_claims  12002 non-null  int64
#  14  witness_present     12002 non-null  object
# ...

# %%
#2
df.head(10)
df.head()
# Out:
#    claim_number  age_of_driver gender marital_status  safety_rating  \
# 0        414724             39      M              1             73
# 1        269568             33      M              1             72
# 2        974592             31      M              1             76
# 3        995328             53      F              1             93
# 4       1140480             41      M              1             87
#
#    annual_income  high_education  address_change property_status  zip_code  \
# 0        58612.8               1               0             Own     50048
# 1        35936.0               0               1             Own     50006
# 2        84940.8               1               1             Own     15021
# 3        73526.4               0               1             Own     85027
# 4        59403.2               1               0             Own     80046
#
#    ... vehicle_category vehicle_price vehicle_color  total_claim injury_claim  \
# ...

# %%
#3
df.tail()
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 11997     621727488             34      M              1             88
# 11998     621810432             65      F              1             97
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# 11997        66505.6               1               1            Rent
# 11998        23315.2               1               0            Rent
# 11999        66505.6               0               1             Own
# 12000        76409.6               1               0             Own
# 12001        70915.2               1               0            Rent
#
#        zip_code  ... vehicle_category vehicle_price vehicle_color  \
# ...

# %%
#4
df.shape #(12002, 29)
# Out:
# (12002, 29)

# %%
#5
df.shape[0]
df.shape[1]
# Out:
# 29

# %%
#6
df.columns
# Out:
# Index(['claim_number', 'age_of_driver', 'gender', 'marital_status',
#        'safety_rating', 'annual_income', 'high_education', 'address_change',
#        'property_status', 'zip_code', 'claim_date', 'claim_day_of_week',
#        'accident_site', 'past_num_of_claims', 'witness_present', 'liab_prct',
#        'channel', 'police_report', 'age_of_vehicle', 'vehicle_category',
#        'vehicle_price', 'vehicle_color', 'total_claim', 'injury_claim',
#        'policy deductible', 'annual premium', 'days open', 'form defects',
#        'fraud reported'],
#       dtype='object')

# %%
#7
df.index
# Out:
# RangeIndex(start=0, stop=12002, step=1)

# %%
#8
df['age_of_driver'].nunique()
# Out:
# 81

# %%
#9
df.isnull().sum()
# Out:
# claim_number          0
# age_of_driver         0
# gender                0
# marital_status        0
# safety_rating         0
# annual_income         0
# high_education        0
# address_change        0
# property_status       0
# zip_code              0
# claim_date            0
# claim_day_of_week     0
# accident_site         0
# past_num_of_claims    0
# witness_present       0
# liab_prct             0
# channel               0
# police_report         0
# age_of_vehicle        0
# vehicle_category      0
# vehicle_price         0
# vehicle_color         0
# total_claim           0
# injury_claim          0
# policy deductible     0
# annual premium        0
# days open             0
# form defects          0
# fraud reported        8
# dtype: int64

# %%
#10
df[df['fraud reported'].isnull()]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 1289      209786112             32      F              0             82
# 3211      519250176             48      F              1             84
# 4736      312408576             51      F              1             87
# 5486      569763072             24      F              1             58
# 8267      260257536             53      M              1             74
# 9319      364372992             54      M              0             88
# 9864      416233728             37      F              1             83
# 10388     467907840             56      M              1             77
#
#        annual_income  high_education  address_change property_status  \
# 1289         55448.0               1               0            Rent
# 3211         61915.2               1               0            Rent
# 4736         62924.8               1               1             Own
# ...

# %%
#11
df['age_of_driver'].sum()
# Out:
# np.int64(522389)

# %%
#12
df.gender.dtype
# Out:
# dtype('O')

# %%
#13
df.describe()
# Out:
#        claim_number  age_of_driver  safety_rating  annual_income  \
# count  1.200200e+04   12002.000000   12002.000000   12002.000000
# mean   3.119801e+08      43.525162      73.702966   63658.226534
# std    1.795997e+08      12.201298      15.378967   17289.704559
# min    1.866240e+05      19.000000       2.000000      -1.600000
# 25%    1.561887e+08      35.000000      66.000000   56899.200000
# 50%    3.121908e+08      43.000000      76.000000   60899.200000
# 75%    4.677938e+08      51.000000      85.000000   64697.600000
# max    6.220385e+08     278.000000     100.000000  257313.600000
#
#        high_education  address_change      zip_code  past_num_of_claims  \
# count    12002.000000    12002.000000  12002.000000        12002.000000
# mean         0.698134        0.576737  49762.387269            0.494918
# std          0.459087        0.494097  29133.180765            0.956002
# min          0.000000        0.000000      0.000000            0.000000
# ...

# %%
#14
df["gender"].value_counts()
# Out:
# gender
# M    6216
# F    5786
# Name: count, dtype: int64

# %%
#15
df["annual_income"].mean()
# Out:
# np.float64(63658.226533577734)

# %%
#16
df.sort_values(by="age_of_driver")
# Out:
#       claim_number  age_of_driver gender marital_status  safety_rating  \
# 5257     492459264             19      M              1             60
# 4278     156100608             19      F              1             94
# 2625     425647872             19      M              1             86
# 4003      59470848             19      M              0             74
# 1306     212958720             19      F              0             87
# ...            ...            ...    ...            ...            ...
# 7702     202652928            101      M              1             42
# 5426     546600960            123      F              1             74
# 5644       1078272            180      F              1             87
# 7542     186665472            249      M              1             94
# 7329     165867264            278      F              1             76
#
#       annual_income  high_education  address_change property_status  zip_code  \
# ...

# %%
#17
df.groupby("accident_site").sum()
# Out:
#                 claim_number  age_of_driver  \
# accident_site
# Highway         774833402884         108655
# Local          1854603848448         258323
# Parking Lot    1114947908352         155411
#
#                                                           gender  \
# accident_site
# Highway        MFMFFFFFMFFMMFMMMFMFFMFMFFFMFFFMMFFMMMFMMFMMFM...
# Local          MMMFFMMFMFFMMFFFMMFFFMFMMMMFFFFFFFFFFMMFFMMMFF...
# Parking Lot    FMFFFMFMFMMMMFMFFFMFFFMFFFMMMMFFFFMMMMFFMFFFFF...
#
#                                                   marital_status  \
# accident_site
# Highway        1010101011110001011110111111111111110001110010...
# Local          1110011000001010111011001011110111110111110111...
# Parking Lot    1111111011011011111110001100100100010000110110...
#
#                safety_rating  annual_income  high_education  address_change  \
# accident_site
# Highway               184831   1.572544e+08            1800            1452
# ...

# %%
#18
df.sample(5)
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 1219      200081664             35      M              1             67
# 11566     580939776             34      F              1             43
# 11868     608539392             44      F              0             71
# 7988      231061248             41      F              0             91
# 11556     579032064             47      F              1             48
#
#        annual_income  high_education  address_change property_status  \
# 1219         56896.0               1               0             Own
# 11566        56408.0               1               0             Own
# 11868        60524.8               1               0             Own
# 7988         59392.0               1               0            Rent
# 11556        61585.6               0               1             Own
#
#        zip_code  ... vehicle_category vehicle_price vehicle_color  \
# ...

# %%
#19
df.duplicated()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#20
df[df['age_of_driver'] > 25]
# Out:
#        claim_number  age_of_driver gender marital_status  safety_rating  \
# 0            414724             39      M              1             73
# 1            269568             33      M              1             72
# 2            974592             31      M              1             76
# 3            995328             53      F              1             93
# 4           1140480             41      M              1             87
# ...             ...            ...    ...            ...            ...
# 11997     621727488             34      M              1             88
# 11998     621810432             65      F              1             97
# 11999     621872640             64      F              1             87
# 12000     621914112             34      F              1             70
# 12001     621955584             45      M              1             61
#
#        annual_income  high_education  address_change property_status  \
# ...
